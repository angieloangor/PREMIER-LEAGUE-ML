# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "enviroment_bj").exists():
    ROOT = ROOT.parent

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("project_root:", ROOT)
# Out:
# project_root: C:\Users\alejo\OneDrive\Escritorio\PremierLeagueML

# %% [markdown]
# ---

# %%
from src.models.select_best_model import *

top_models = rank_classifier_bundles(
    runs_root=r"C:\Users\alejo\OneDrive\Escritorio\PremierLeagueML\outputs\model_runs\advanced_match_predictor\stage2_classifier_runs",
    top_k=7,
)

top_models
# Out:
# [{'run_name': 'clean_dominance_index__random_forest_regressor+clean_dominance_index+feature_generator__ridge_classifier+extra',
#   'classifier_name': 'ridge_classifier',
#   'feature_mode': 'extra',
#   'score': 0.5443207217933206,
#   'cv_accuracy': 0.5105263157894737,
#   'cv_f1_weighted': 0.5057849408209518,
#   'test_accuracy': 0.576271186440678,
#   'test_f1_weighted': 0.5847004441221788,
#   'bundle_dir': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\PremierLeagueML\\outputs\\model_runs\\advanced_match_predictor\\stage2_classifier_runs\\clean_dominance_index__random_forest_regressor+clean_dominance_index+feature_generator__ridge_classifier+extra',
#   'classifier_artifact_path': 'C:\\Users\\alejo\\OneDrive\\Escritorio\\PremierLeagueML\\outputs\\model_runs\\advanced_match_predictor\\stage2_classifier_runs\\clean_dominance_index__random_forest_regressor+clean_dominance_index+feature_generator__ridge_classifier+extra\\classifier.joblib',
#   'run_type': 'advanced_stage2',
# ...

# %%
result = delete_bad_classifier_runs(
    runs_root=r"C:\Users\alejo\OneDrive\Escritorio\PremierLeagueML\outputs\model_runs\advanced_match_predictor\stage2_classifier_runs",
    min_test_accuracy=0.49,
    dry_run=True,
)

result
# Out:
# runs_root: C:\Users\alejo\OneDrive\Escritorio\PremierLeagueML\outputs\model_runs\advanced_match_predictor\stage2_classifier_runs
# run_summary.json encontrados: 94
# Umbral mínimo test_accuracy: 0.49
# dry_run: True
# [KEEP] clean_dominance_index__catboost_regressor+clean_dominance_index+feature_generator__catboost_classifier+extra | test_accuracy=0.5424
# [KEEP] clean_dominance_index__catboost_regressor+clean_dominance_index+feature_generator__catboost_classifier+lasso_selected | test_accuracy=0.5593
# [KEEP] clean_dominance_index__catboost_regressor+clean_dominance_index+feature_generator__elasticnet_classifier+extra | test_accuracy=0.4915
# [KEEP] clean_dominance_index__catboost_regressor+clean_dominance_index+feature_generator__lightgbm_classifier+extra | test_accuracy=0.5424
# [KEEP] clean_dominance_index__catboost_regressor+clean_dominance_index+feature_generator__ridge_classifier+extra | test_accuracy=0.5424
# ...
