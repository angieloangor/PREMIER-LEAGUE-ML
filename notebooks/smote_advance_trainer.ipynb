# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
import os
import warnings

warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"
os.environ["LIGHTGBM_VERBOSITY"] = "-1"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import warnings

warnings.filterwarnings("ignore")

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "enviroment_bj").exists():
    ROOT = ROOT.parent

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("project_root:", ROOT)
# Out:
# project_root: C:\Users\alejo\OneDrive\Escritorio\PremierLeagueML

# %%
from src.dataops import build_data_artifacts
from src.models import run_match_model_experiments

artifacts = build_data_artifacts()
match_features = artifacts["match_features"]

report = run_match_model_experiments(
    match_features=match_features,
    regressors=[
        "linear_regression",
        "knn_regressor",
        "ridge_regressor",
        "elasticnet_regressor",
        "random_forest_regressor",
        "xgboost_regressor", 'catboost_regressor' ,'lightgbm_regressor' ,'torch_regressor'
    ],
    classifiers=[
        "knn_classifier",
        "ridge_classifier",
        "elasticnet_classifier",
        "random_forest_classifier",
        "xgboost_classifier", 'catboost_classifier' ,'lightgbm_classifier' ,'torch_classifier'
    ],
    winner_feature_set="winner_default",
    feature_modes=["normal", "extra", "lasso_selected", "poly2_lasso"],
    search_iterations=10,
    smote=True,
    advance_modeling=True,
    stage1_feature_set="history_only",
    stage1_target_set="candidate_indices",
    stage1_top_k=3,
    stage1_min_r2=0.10,
    session_name="advanced_match_predictor" ,include_all=True)
# Out:
# Advance modeling: on
# Stage 1 feature generators planned: 9
# Stage 1 candidate metrics: 5
# Stage 2 classifiers planned: 8
# Stage 2 feature modes: ['normal', 'extra', 'lasso_selected', 'poly2_lasso']
# Classification SMOTE: on
# Include all best generated indices: on
# [metric 1/5] Stage 1 target: threat_index
#   [stage1 1/9] Training linear_regression for threat_index
#       mean CV R2:  -0.4883    test R2:     0.0906
#   [stage1 2/9] Training knn_regressor for threat_index
#       mean CV R2:  0.0461    test R2:     0.1234
#   [stage1 3/9] Training ridge_regressor for threat_index
#       mean CV R2:  0.1125    test R2:     0.1253
#   [stage1 4/9] Training elasticnet_regressor for threat_index
#       mean CV R2:  0.1154    test R2:     0.1383
#   [stage1 5/9] Training random_forest_regressor for threat_index
#       mean CV R2:  0.1434    test R2:     0.1268
#   [stage1 6/9] Training xgboost_regressor for threat_index
#       mean CV R2:  0.1164    test R2:     0.0668
# ...
