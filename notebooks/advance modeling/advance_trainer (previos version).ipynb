# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
import os
import warnings

warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"
os.environ["LIGHTGBM_VERBOSITY"] = "-1"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import warnings

warnings.filterwarnings("ignore")

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "enviroment_bj").exists():
    ROOT = ROOT.parent

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("project_root:", ROOT)
# Out:
# project_root: C:\Users\alejo\OneDrive\Escritorio\PremierLeagueML

# %%
try:
    import catboost
    from catboost import CatBoostClassifier, CatBoostRegressor

    print("CatBoost está disponible.")
    print(f"Versión: {catboost.__version__}")

except ImportError as e:
    print("CatBoost NO está disponible en este entorno.")
    print("Error:", e)
# Out:
# CatBoost está disponible.
# Versión: 1.2.10

# %%
try:
    import lightgbm as lgb
    from lightgbm import LGBMClassifier, LGBMRegressor

    print("LightGBM está disponible.")
    print(f"Versión: {lgb.__version__}")

except ImportError as e:
    print("LightGBM NO está disponible en este entorno.")
    print("Error:", e)
# Out:
# LightGBM está disponible.
# Versión: 4.6.0

# %%
try:
    import torch 
    import torch.nn as nn 

    print("Torch está disponible.")
    print(f"Versión: {lgb.__version__}")

except ImportError as e:
    print("Torch NO está disponible en este entorno.")
    print("Error:", e)
# Out:
# Torch está disponible.
# Versión: 4.6.0

# %%
from src.dataops import build_data_artifacts
from src.models import list_models, run_match_model_experiments

artifacts = build_data_artifacts()
match_features = artifacts["match_features"]

print(list_models(stage="regression"))
print(list_models(stage="classification"))

report = run_match_model_experiments(
    match_features=match_features,
    regressors=[
        "linear_regression",
        "ridge_regressor",
        "elasticnet_regressor",
        "random_forest_regressor",
        "xgboost_regressor",
        "catboost_regressor",
        "lightgbm_regressor",
        "torch_regressor",
    ],
    classifiers=[
        "ridge_classifier",
        "elasticnet_classifier",
        "random_forest_classifier",
        "xgboost_classifier",
        "catboost_classifier",
        "lightgbm_classifier",
        "torch_classifier",
    ],
    explicit_pairs=[
        ("linear_regression", "ridge_classifier"),
        ("linear_regression", "elasticnet_classifier"),
        ("linear_regression", "xgboost_classifier"),

        ("ridge_regressor", "ridge_classifier"),
        ("ridge_regressor", "elasticnet_classifier"),
        ("ridge_regressor", "xgboost_classifier"),

        ("elasticnet_regressor", "ridge_classifier"),
        ("elasticnet_regressor", "elasticnet_classifier"),
        ("elasticnet_regressor", "lightgbm_classifier"),

        ("random_forest_regressor", "random_forest_classifier"),
        ("random_forest_regressor", "xgboost_classifier"),
        ("random_forest_regressor", "lightgbm_classifier"),

        ("xgboost_regressor", "random_forest_classifier"),
        ("xgboost_regressor", "xgboost_classifier"),
        ("xgboost_regressor", "catboost_classifier"),

        ("catboost_regressor", "random_forest_classifier"),
        ("catboost_regressor", "catboost_classifier"),
        ("catboost_regressor", "lightgbm_classifier"),

        ("lightgbm_regressor", "xgboost_classifier"),
        ("lightgbm_regressor", "catboost_classifier"),
        ("lightgbm_regressor", "lightgbm_classifier"),

        ("torch_regressor", "xgboost_classifier"),
        ("torch_regressor", "lightgbm_classifier"),
        ("torch_regressor", "torch_classifier"),
    ],
    goal_feature_set="goals_default",
    winner_feature_set="winner_default",
    feature_modes=["normal", "extra", "lasso_selected", "poly2_lasso"],
    search_iterations=15,
    include_stage1_prediction=True,
    session_name="cpu_match_sweep_v3_linear_and_logit_no_leakage")
# Out:
# ['catboost_regressor', 'elasticnet_regressor', 'lightgbm_regressor', 'linear_regression', 'random_forest_regressor', 'ridge_regressor', 'torch_regressor', 'xgboost_regressor']
# ['catboost_classifier', 'elasticnet_classifier', 'lightgbm_classifier', 'random_forest_classifier', 'ridge_classifier', 'torch_classifier', 'xgboost_classifier']
# Planned runs: 96
# - linear_regression+ridge_classifier+normal: 1 regression combos, 8 classification combos
# - linear_regression+ridge_classifier+extra: 1 regression combos, 8 classification combos
# - linear_regression+ridge_classifier+lasso_selected: 1 regression combos, 8 classification combos
# - linear_regression+ridge_classifier+poly2_lasso: 1 regression combos, 8 classification combos
# - linear_regression+elasticnet_classifier+normal: 1 regression combos, 56 classification combos
# - linear_regression+elasticnet_classifier+extra: 1 regression combos, 56 classification combos
# ...
